# %% [markdown]
# <a href="https://colab.research.google.com/github/bhuvighosh3/store_codes/blob/main/Pdf_hackmania.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install openai
# !pip install youtube_dl
# !pip install youtube_transcript_api
# !pip install torchaudio
# !pip install sentencepiece
# !pip install sacremoses
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 34.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895241 sha256=fbef5708fea24df719b9ae6e588a3164fdc4bf8b3cfa21088afdf4e3bd51b5cc
#   Stored in directory: /root/.cache/pip/wheels/00/24/97/a2ea5324f36bc626e1ea0267f33db6aa80d157ee977e9e42fb
# Successfully built sacremoses
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 67.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 79.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 86.3 MB/s eta 0:00:00
# ...

# %%
# !pip install PyPDF2
import PyPDF2

# Replace 'your_pdf_file.pdf' with the path to your PDF file
pdf_file_path = '/content/Ch 1- Resources and Development.pdf'

# Create a PDF file reader object
pdf_reader = PyPDF2.PdfReader(open(pdf_file_path, 'rb'))

# Initialize an empty string to store the extracted text
text = ''

# Iterate through each page in the PDF
for page_num in range(len(pdf_reader.pages)):
    page = pdf_reader.pages[page_num]

    # Extract text from the current page
    page_text = page.extract_text()

    # Append the page text to the overall text
    text += page_text

# Print or use the extracted text
print(text)
# Out:
# ...
# Everything available in our envir onment
# which can be used to satisfy our needs,
# provided, it is technologically accessible,
# economically feasible and culturally
# acceptable can be termed as ‘Resource’.
# The process of transformation of things
# available in our environment involves an
# inter active  relationship between nature,
# technology and institutions. Human beings
# interact with nature through technology and
# create institutions to accelerate their
# economic development.
# Do you think that resources are free
# gifts of nature as is assumed by many?
# They are not. Resources are a function of
# human activities. Human beings themselves
# are essential components of resources. They
# transform material available in our
# environment into resources and use them.
# These resources can be classified in the
# following way s–
# (a)On the basis of origin – biotic and abiotic
# (b)On the basis of exhaustibility – renewable
# and non-renewable
# ...

# %%
import openai
import textwrap
import pandas as pd

def split_text_into_chunks(text, max_chunk_size):
    return textwrap.wrap(text, max_chunk_size)

openai.api_key = "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"
max_chunk_size = 4000
transcript_chunks = split_text_into_chunks(text, max_chunk_size)
qa_pairs = []

for chunk in transcript_chunks:
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo-16k",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"{chunk}\n\n Generate questions and answers for this text. Start question with Q. and answer with A."},
        ],
        max_tokens=500,  # Adjust the max tokens based on your needs
        temperature=0.5
    )



    # Extract all responses and split them into questions and answers
    for choice in response['choices']:
        qa_pair = choice['message']['content'].strip()
        # Split the QA pair based on "Q." and "A." lines
        qa_list = qa_pair.split('\n')
        questions = []
        answers = []

        for line in qa_list:
            if line.startswith("Q."):
                questions.append(line[2:].strip())  # Remove "Q." and leading spaces
            elif line.startswith("A."):
                answers.append(line[2:].strip())  # Remove "A." and leading spaces

        # Create pairs of questions and answers
        for q, a in zip(questions, answers):
            qa_pairs.append((q, a))

print(qa_pair)
# Out:
# Q: What are some methods to control soil erosion in hilly areas?
# A: Some methods to control soil erosion in hilly areas include contour ploughing, terrace cultivation, strip cropping, and planting shelter belts.
#
# Q: Which states in India have black soil and what crop is mainly grown in it?
# A: Three states in India that have black soil are Maharashtra, Uttar Pradesh, and Jharkhand. The crop mainly grown in black soil is cotton.
#
# Q: What type of soil is found in the river deltas of the eastern coast of India and what are its main features?
# A: The type of soil found in the river deltas of the eastern coast of India is alluvial soil. Its main features include being fertile, well-drained, and suitable for the cultivation of paddy and other crops.
#
# Q: What is the main cause of land degradation in Punjab?
# A: The main cause of land degradation in Punjab is intensive cultivation.
#
# Q: Why has the land under forest not increased much since 1960-61 in India?
# ...

# %%
# Create a DataFrame from the QA pairs
qa_pairs_df = pd.DataFrame(qa_pairs, columns=["Question", "Answer"])

# Print the DataFrame
print(qa_pairs_df)
# Out:
#                                              Question  \
# 0                What is the definition of resources?
# 1      Are resources considered free gifts of nature?
# 2                    How can resources be classified?
# 3   What are some problems caused by the indiscrim...
# 4                 Why is resource planning essential?
# 5                    What is sustainable development?
# 6                                  What is Agenda 21?
# 7   Can you provide examples of stock and reserve ...
# 8   How would the exhaustion of oil supply affect ...
# 9   What can be done to combat resource depletion ...
# 10  What are the different relief features found i...
# 11         What percentage of land in India is plain?
# 12  What are the different purposes for which land...
# 13                         What is the net sown area?
# 14   What factors determine the use of land in India?
# 15    What is the concept of sustainable development?
# ...

# %%
new_df=qa_pairs_df.head(10)

# %%
# Ask the user for input for each question and populate the "user_answer" column
for index, row in new_df.iterrows():
    user_answer = input(f"Question {index + 1}: {row['Question']} ")
    new_df.at[index, "user_answer"] = user_answer
# Out:
# Question 1: What is the definition of resources? Resources are valuable assets or entities, whether tangible or intangible, used to accomplish specific purposes or goals.
# <ipython-input-12-e6e9d1d91ba6>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.at[index, "user_answer"] = user_answer
# Question 2: Are resources considered free gifts of nature? Resources are often considered "free gifts of nature," as they are naturally occurring assets provided by the environment.
# Question 3: How can resources be classified? natural resources and human resources
# Question 4: What are some problems caused by the indiscriminate use of resources? recycling
# ...

# %%
new_df.head()
# Out:
#                                             Question  \
# 0               What is the definition of resources?
# 1     Are resources considered free gifts of nature?
# 2                   How can resources be classified?
# 3  What are some problems caused by the indiscrim...
# 4                Why is resource planning essential?
#
#                                               Answer  \
# 0  Resources are everything available in our envi...
# 1  No, resources are not free gifts of nature. Th...
# 2  Resources can be classified based on their ori...
# 3  The indiscriminate use of resources has led to...
# 4  Resource planning is essential for sustainable...
#
#                                          user_answer
# 0  Resources are valuable assets or entities, whe...
# 1  Resources are often considered "free gifts of ...
# 2              natural resources and human resources
# 3                                          recycling
# 4   Resource planning is essential because it hel...

# %%
import pandas as pd
from difflib import SequenceMatcher

# Create a function to calculate similarity using SequenceMatcher
def calculate_similarity(str1, str2):
    similarity = SequenceMatcher(None, str1, str2).ratio()
    return similarity

scores = []

# Example: Load your DataFrame
# df = pd.read_csv('your_dataframe.csv')

# Iterate through rows and calculate similarity for each row
for index, row in new_df.iterrows():
    answer = row['Answer']
    users_answer = row['user_answer']

    # Calculate similarity between answer and user_answer
    similarity_score = calculate_similarity(answer.lower(), user_answer.lower())
    scores.append(similarity_score)

# Now, 'scores' will contain the similarity scores for each pair of strings.

# %%
new_df['Score']=scores
# Out:
# <ipython-input-18-d708ce5b7b94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Score']=scores

# %%
new_df.head()
# Out:
#                                             Question  \
# 0               What is the definition of resources?
# 1     Are resources considered free gifts of nature?
# 2                   How can resources be classified?
# 3  What are some problems caused by the indiscrim...
# 4                Why is resource planning essential?
#
#                                               Answer  \
# 0  Resources are everything available in our envi...
# 1  No, resources are not free gifts of nature. Th...
# 2  Resources can be classified based on their ori...
# 3  The indiscriminate use of resources has led to...
# 4  Resource planning is essential for sustainable...
#
#                                          user_answer     Score
# 0  Resources are valuable assets or entities, whe...  0.189189
# 1  Resources are often considered "free gifts of ...  0.228261
# 2              natural resources and human resources  0.175439
# 3                                          recycling  0.165714
# ...

# %%
new_df["Correction"] =new_df["Score"].apply(lambda x: "Correct" if x >= 0.17 else "Wrong")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-605d23f394e3> in <cell line: 1>()
# ----> 1 new_df["Correction"] =new_df["Score"].apply(lambda x: "Correct" if x >= 0.17 else "Wrong")
#
# NameError: name 'new_df' is not defined

# %%
new_df.head()
# Out:
#                                             Question  \
# 0               What is the definition of resources?
# 1     Are resources considered free gifts of nature?
# 2                   How can resources be classified?
# 3  What are some problems caused by the indiscrim...
# 4                Why is resource planning essential?
#
#                                               Answer  \
# 0  Resources are everything available in our envi...
# 1  No, resources are not free gifts of nature. Th...
# 2  Resources can be classified based on their ori...
# 3  The indiscriminate use of resources has led to...
# 4  Resource planning is essential for sustainable...
#
#                                          user_answer     Score Correction
# 0  Resources are valuable assets or entities, whe...  0.189189    Correct
# 1  Resources are often considered "free gifts of ...  0.228261    Correct
# 2              natural resources and human resources  0.175439    Correct
# ...

# %%
accuracy=(sum(new_df['Correction']=='Correct')/10)*100
accuracy
# Out:
# 90.0

# %%
new_df.to_csv('answerstore.csv')
